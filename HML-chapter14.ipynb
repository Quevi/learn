# %%
from sklearn.datasets import load_sample_image
import numpy as np

# %%
import tensorflow as tf

# %%
import tensorflow.keras as keras

# %%
import matplotlib.pyplot as plt

# %%
china = load_sample_image('china.jpg') / 255.0
flower = load_sample_image('flower.jpg') / 255.0

# %%
images = np.array([china, flower])

# %%
batch_size, height, width, channels = images.shape

# %%
# create filters
filters = np.zeros(shape=(7, 7, channels, 2), dtype=np.float32)
filters[:, 3, :, 0] = 1
filters[3, :, :, 1] = 1

# %%
outputs = tf.nn.conv2d(images, filters, strides=1, padding='SAME')

# %% [markdown]
# # Tackle fashion mnist with CNN

# %%
cnn_model = keras.models.Sequential([
    keras.layers.Conv2D(64, 7, activation='relu', padding='SAME', input_shape=[28, 28, 1]),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128, 3, activation='relu', padding='SAME'),
    keras.layers.Conv2D(128, 3, activation='relu', padding='SAME'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(256, 3, activation='relu', padding='SAME'),
    keras.layers.Conv2D(256, 3, activation='relu', padding='SAME'),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation='softmax')
])

# %%
data = keras.datasets.fashion_mnist.load_data()
# 分离出训练集、验证集和测试集
(X_train_full, y_train_full), (X_test, y_test) = data

X_train, X_val = X_train_full[:55000] / 255.0, X_train_full[55000:] / 255.0

y_train, y_val = y_train_full[:55000], y_train_full[55000:]

# %%
cnn_model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
X_train_reshaped = X_train.reshape(X_train.shape + (1, ))
X_val_reshaped = X_val.reshape(X_val.shape + (1, ))

# %%
cnn_model.fit(X_train_reshaped, y_train, validation_data=(X_val_reshaped, y_val), epochs=30)
# Out:
# Train on 55000 samples, validate on 5000 samples
# Epoch 1/30
# 55000/55000 [==============================] - 14s 247us/sample - loss: 1.2465 - accuracy: 0.5476 - val_loss: 0.6370 - val_accuracy: 0.7616
# Epoch 2/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.6937 - accuracy: 0.7474 - val_loss: 0.5060 - val_accuracy: 0.8142
# Epoch 3/30
# 55000/55000 [==============================] - 13s 244us/sample - loss: 0.5663 - accuracy: 0.7952 - val_loss: 0.4418 - val_accuracy: 0.8318
# Epoch 4/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.5011 - accuracy: 0.8208 - val_loss: 0.3992 - val_accuracy: 0.8490
# Epoch 5/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.4633 - accuracy: 0.8347 - val_loss: 0.3772 - val_accuracy: 0.8546
# Epoch 6/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.4305 - accuracy: 0.8461 - val_loss: 0.3518 - val_accuracy: 0.8658
# Epoch 7/30
# 55000/55000 [==============================] - 13s 244us/sample - loss: 0.4068 - accuracy: 0.8565 - val_loss: 0.3397 - val_accuracy: 0.8704
# Epoch 8/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.3874 - accuracy: 0.8621 - val_loss: 0.3383 - val_accuracy: 0.8712
# Epoch 9/30
# 55000/55000 [==============================] - 13s 244us/sample - loss: 0.3697 - accuracy: 0.8672 - val_loss: 0.3298 - val_accuracy: 0.8766
# Epoch 10/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.3576 - accuracy: 0.8727 - val_loss: 0.3149 - val_accuracy: 0.8822
# Epoch 11/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.3417 - accuracy: 0.8786 - val_loss: 0.3089 - val_accuracy: 0.8814
# Epoch 12/30
# 55000/55000 [==============================] - 13s 244us/sample - loss: 0.3296 - accuracy: 0.8820 - val_loss: 0.3095 - val_accuracy: 0.8828
# Epoch 13/30
# 55000/55000 [==============================] - 13s 244us/sample - loss: 0.3212 - accuracy: 0.8851 - val_loss: 0.2955 - val_accuracy: 0.8902
# Epoch 14/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.3104 - accuracy: 0.8888 - val_loss: 0.2928 - val_accuracy: 0.8884
# Epoch 15/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.3001 - accuracy: 0.8934 - val_loss: 0.2838 - val_accuracy: 0.8904
# Epoch 16/30
# 55000/55000 [==============================] - 13s 244us/sample - loss: 0.2955 - accuracy: 0.8941 - val_loss: 0.2750 - val_accuracy: 0.8944
# Epoch 17/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.2849 - accuracy: 0.8982 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 18/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.2779 - accuracy: 0.8999 - val_loss: 0.2650 - val_accuracy: 0.8990
# Epoch 19/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.2707 - accuracy: 0.9029 - val_loss: 0.2689 - val_accuracy: 0.8996
# Epoch 20/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.2633 - accuracy: 0.9044 - val_loss: 0.2664 - val_accuracy: 0.8992
# Epoch 21/30
# 55000/55000 [==============================] - 13s 244us/sample - loss: 0.2566 - accuracy: 0.9081 - val_loss: 0.2720 - val_accuracy: 0.9022
# Epoch 22/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.2522 - accuracy: 0.9094 - val_loss: 0.2654 - val_accuracy: 0.9032
# Epoch 23/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.2451 - accuracy: 0.9123 - val_loss: 0.2511 - val_accuracy: 0.9036
# Epoch 24/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.2366 - accuracy: 0.9132 - val_loss: 0.2584 - val_accuracy: 0.9062
# Epoch 25/30
# 55000/55000 [==============================] - 13s 244us/sample - loss: 0.2340 - accuracy: 0.9156 - val_loss: 0.2458 - val_accuracy: 0.9030
# Epoch 26/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.2255 - accuracy: 0.9191 - val_loss: 0.2516 - val_accuracy: 0.9090
# Epoch 27/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.2181 - accuracy: 0.9228 - val_loss: 0.2441 - val_accuracy: 0.9096
# Epoch 28/30
# 55000/55000 [==============================] - 13s 242us/sample - loss: 0.2107 - accuracy: 0.9247 - val_loss: 0.2581 - val_accuracy: 0.9058
# Epoch 29/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.2095 - accuracy: 0.9249 - val_loss: 0.2437 - val_accuracy: 0.9102
# Epoch 30/30
# 55000/55000 [==============================] - 13s 243us/sample - loss: 0.2014 - accuracy: 0.9261 - val_loss: 0.2541 - val_accuracy: 0.9096

# %%
print(cnn_model.evaluate(X_test.reshape(X_test.shape + (1, )) / 255, y_test))
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.2808810354039073, 0.9121]
